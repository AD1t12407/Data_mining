# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/aditinarayan/Documents/btech_yr_3/Data_mining/datasets/StudentsPerformance.csv",header=0)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_categorical=df.select_dtypes(exclude=[np.int64])
df_categorical
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
df_categorical.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df_categorical['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df_categorical['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df_categorical['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df_categorical['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
df_categorical['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
df_categorical.gender.replace({"male" :0,"female" :1}, inplace=True)
df_categorical
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         1        group B           bachelor's degree      standard
# 1         1        group C                some college      standard
# 2         1        group B             master's degree      standard
# 3         0        group A          associate's degree  free/reduced
# 4         0        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       1        group E             master's degree      standard
# 996       0        group C                 high school  free/reduced
# 997       1        group C                 high school  free/reduced
# 998       1        group D                some college      standard
# 999       1        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
df_categorical['race/ethnicity'].replace({'group A':0,'group E':1,'group B':2,'group D':3,'group C':4},inplace= True)
df_categorical
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0         1               2           bachelor's degree      standard
# 1         1               4                some college      standard
# 2         1               2             master's degree      standard
# 3         0               0          associate's degree  free/reduced
# 4         0               4                some college      standard
# ..      ...             ...                         ...           ...
# 995       1               1             master's degree      standard
# 996       0               4                 high school  free/reduced
# 997       1               4                 high school  free/reduced
# 998       1               3                some college      standard
# 999       1               3                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
df_categorical['parental level of education'].replace({"master's degree":0,"bachelor's degree":1,'some high school':2,'high school':3,"associate's degree":4,'some college':5},inplace= True)
df_categorical
# Out:
#      gender  race/ethnicity  parental level of education         lunch  \
# 0         1               2                            1      standard
# 1         1               4                            5      standard
# 2         1               2                            0      standard
# 3         0               0                            4  free/reduced
# 4         0               4                            5      standard
# ..      ...             ...                          ...           ...
# 995       1               1                            0      standard
# 996       0               4                            3  free/reduced
# 997       1               4                            3  free/reduced
# 998       1               3                            5      standard
# 999       1               3                            5  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# ...

# %%
df_categorical['lunch'].replace({"standard" :0,"free/reduced" :1}, inplace=True)
df_categorical
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               2                            1      0
# 1         1               4                            5      0
# 2         1               2                            0      0
# 3         0               0                            4      1
# 4         0               4                            5      0
# ..      ...             ...                          ...    ...
# 995       1               1                            0      0
# 996       0               4                            3      1
# 997       1               4                            3      1
# 998       1               3                            5      0
# 999       1               3                            5      1
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# 3                      none
# 4                      none
# ...

# %%
df_categorical['test preparation course'].replace({"none":0,"completed":1},inplace=True)
df_categorical
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               2                            1      0
# 1         1               4                            5      0
# 2         1               2                            0      0
# 3         0               0                            4      1
# 4         0               4                            5      0
# ..      ...             ...                          ...    ...
# 995       1               1                            0      0
# 996       0               4                            3      1
# 997       1               4                            3      1
# 998       1               3                            5      0
# 999       1               3                            5      1
#
#      test preparation course
# 0                          0
# 1                          1
# 2                          0
# 3                          0
# 4                          0
# ...
